# %% [markdown]
# <a href="https://colab.research.google.com/github/OSCARDAN37/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/EL_Profe_circulo_Oscar_Flores_1389.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Oscar Flores NL = 19 - Fecha 24/Marzo/2026
# ---
# # Calcular Area y perimetro de un circulo
# ![Logo de Markdown](https://raw.githubusercontent.com/OSCARDAN37/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/circulo%20area%20perimetro.JPG)
#
# ---
# ## Formula para calcular Area
# $A = \pi\cdot r^2$
# ---
# ## Formula para calcular perimetro
# $P = 2\cdot\pi\cdot r$
# ---
# ## Datos de entrada
# $r ?$
# ---
# ## Diagrama de flujo LucidChart
# ![Lgo de Markdown](https://raw.githubusercontent.com/OSCARDAN37/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# Calcular area y perimetro de un circulo
# variables A, P, r
# formulas A = pi * r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor de r: "))
A = math.pi*r**2
P = 2*math.pi*r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
print("Oscar Flores NL = 19")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor de r: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Oscar Flores NL = 19

# %% [markdown]
# # Relacion entre codigo y DF en Tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/OSCARDAN37/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/tldraw%20DF%20y%20codigo.png)
